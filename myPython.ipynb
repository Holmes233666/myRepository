# %%
print("hello world!")
# Out:
# hello world!

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
A = pd.DataFrame(np.arange(10))

# %%
x = np.arange(1,10)
y = x
plt.plot(x,y)
